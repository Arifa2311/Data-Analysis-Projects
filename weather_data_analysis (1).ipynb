# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Admin\Downloads\Weather_Data.csv")

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    -1.3              -3.5         18                9
# 1      1/1/2012 1:00     7.4               2.8         20               24
# 2      1/1/2012 2:00    15.7              13.4         21               26
# 3      1/1/2012 3:00     4.9              -2.6         27               15
# 4      1/1/2012 4:00   -13.4             -19.7         30                4
# ...              ...     ...               ...        ...              ...
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa        Weather
# ...

# %%
#1.find all the unique "wind speed" values in the data

# %%
data_copy["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
#2.find the number of times when the "weather is exactly clear"

# %%
a=data_copy.groupby("Weather")

# %%
a.get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#3.find the number of times when the "wind speed was exactly 4km/h"

# %%
b=data_copy.groupby("Wind Speed_km/h")

# %%
b.get_group(4)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
#4.find out all the null values in the dataset

# %%
np.sum(data_copy.isnull().sum().values)
# Out:
# 0

# %%
#5.rename the column name "weather" of the dataframe to "weather condition"

# %%
data_copy.rename(columns={"Weather":"Weather Condition"},inplace=True)

# %%
data_copy
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    -1.3              -3.5         18                9
# 1      1/1/2012 1:00     7.4               2.8         20               24
# 2      1/1/2012 2:00    15.7              13.4         21               26
# 3      1/1/2012 3:00     4.9              -2.6         27               15
# 4      1/1/2012 4:00   -13.4             -19.7         30                4
# ...              ...     ...               ...        ...              ...
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
#6.what is the mean "visibility"

# %%
data_copy["Visibility_km"].mean()
# Out:
# 27.664446721311478

# %%
#7.what is the standard deviation of "pressure" in this data?

# %%
data_copy["Press_kPa"].std()
# Out:
# 0.8440047459486474

# %%
#8.what is the variance of "relative humidity" in this data?

# %%
data_copy["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %%
#9.find all the instances when "snow" was recorded?

# %%
c=data_copy.groupby("Weather Condition")

# %%
c.get_group("Snow")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#10.find all instance when "wind speed is above 24" and "visibility is 25"

# %%
data_copy.loc[(data_copy["Wind Speed_km/h"]>24) & (data_copy["Visibility_km"]==25)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2       1/1/2012 2:00    15.7              13.4         21               26
# 73      4/1/2012 1:00     2.3              -3.4         64               35
# 126     6/1/2012 6:00    10.0               5.4         77               39
# 158    7/1/2012 14:00     1.9              -2.1         87               26
# 184    8/1/2012 16:00    14.2               9.2         35               44
# ...               ...     ...               ...        ...              ...
# 8707   9/27/2012 5:00    -1.0              -6.0         70               33
# 8714  9/28/2012 10:00     2.6               0.3         72               26
# 8738  9/29/2012 10:00    22.8              12.3         80               28
# 8745  9/29/2012 17:00   -10.3             -12.9         82               28
# 8776  9/30/2012 23:00    19.2              13.2         93               43
#
#       Visibility_km  Press_kPa           Weather
# ...

# %%
#11.what is the mean value of each column against each "weather condition"

# %%
data_copy.groupby("Weather Condition").mean()
# Out:
# C:\Users\seeth\AppData\Local\Temp\ipykernel_18100\2339460881.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_copy.groupby("Weather Condition").mean()
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# ...

# %%
#12.what is the maximun & minimum value of each column against each "weather condition"?

# %%
data_copy.groupby("Weather Condition").min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                       1/1/2012 0:00   -23.3
# Cloudy                                     1/1/2012 10:00   -21.4
# Drizzle                                   1/18/2012 16:00     1.1
# Drizzle,Fog                               1/28/2012 12:00     0.0
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00     0.4
# Drizzle,Snow                               3/17/2012 1:00     0.9
# Drizzle,Snow,Fog                           1/25/2012 1:00     0.3
# Fog                                        1/1/2012 13:00   -16.0
# Freezing Drizzle                           2/29/2012 3:00    -9.0
# Freezing Drizzle,Fog                      10/15/2012 4:00    -6.4
# Freezing Drizzle,Haze                       1/6/2012 0:00    -5.8
# Freezing Drizzle,Snow                     1/19/2012 15:00    -8.3
# Freezing Fog                              12/31/2012 2:00   -19.0
# ...

# %%
data_copy.groupby("Weather Condition").max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
#13.show all the records where the weather condition is fog

# %%
d=data_copy.groupby("Weather Condition")

# %%
d.get_group("Fog")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
#14.Find all instance when "weather is clear " or "visibility " is above 40"?

# %%
data_copy.loc[(data_copy["Weather Condition"]=="Clear") | (data_copy["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
#15.A.Find all instance when "weather is clear " and "relative humidity " is greater than 50"
#or
#B."visibility is above 40"?

# %%
data_copy.loc[(data_copy["Weather Condition"]=="Clear") & (data_copy["Rel Hum_%"]>50)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# 241     1/11/2012 1:00   -10.7             -17.8         56               17
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data_copy.loc[(data_copy["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
#
# ...
